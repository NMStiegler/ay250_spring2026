# %% [markdown]
# # Exercise: Precision in Measuring the Power-Law IMF
#
# Noah Stiegler
#
# Stellar Pops AST250 Spring 2026

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Results are in the research_notebook.md file. $\sigma_{\alpha} = \frac{1}{\sqrt{N}} \left[ \frac{1}{(\alpha - 1)^2} - \frac{(\ln r)^2 r^{-(\alpha-1)}}{\left(1 - r^{-(\alpha-1)}\right)^2} \right]^{-1/2}$ where $r$ is $\frac{M_{max}}{M_{min}}$

# %% [markdown]
# ## Problem 2
